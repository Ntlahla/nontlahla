# %%
import pymongo

myclient = pymongo.MongoClient("mongodb://localhost:27017/")
mydb = myclient["Data_Tracker"]
mycol = mydb["Chips"]

mydict=[{"Item":"Simba","Price":18.00},
        {"Item":"Lays","Price":19.99},
        {"Item":"Doritos","Price":20.99},
        {"Item":"Pringles","price":21.99},
        {"Item":"Chetos","Price":10.99},]

mycol.insert_many(mydict)
x = mycol.find()

[print(i) for i in x]

#Remember to uncommment and comment line at the bottom
#mycol.drop()

# %%
import pymongo

myclient = pymongo.MongoClient("mongodb://localhost:27017/")
mydb = myclient["Data_Tracker"]
mycol = mydb["Cooldrinks"]

mydict=[{"Item":"Sprite","Price":14.99},
        {"Item":"Fanta","Price":14.99},
        {"Item":"Coke","Price":20.99},
        {"Item":"Powerade","price":10.99},
        {"Item":"Jive","Price":9.99},]

mycol.insert_many(mydict)
mycol.update


[print(i) for i in x]

#Remember to uncommment and comment line at the bottom
#mycol.drop()

# %%
import pymongo

myclient = pymongo.MongoClient("mongodb://localhost:27017/")
mydb = myclient["Data_Tracker"]
mycol = mydb["Pies"]

mydict=[{"Item":"Steak","Price":15.99},
        {"Item":"Chicken Pie","Price":16.99},
        {"Item":"Cheese Brga","Price":18.99},
        {"Item":"Cherry Pie","price":10.99},
        {"Item":"Chicken & Mrums","Price":15.99},]

mycol.insert_many(mydict)
mycol.update


[print(i) for i in x]

#Remember to uncommment and comment line at the bottom
#mycol.drop()

# %%
import pymongo

myclient = pymongo.MongoClient("mongodb://localhost:27017/")
mydb = myclient["Data_Tracker"]
mycol = mydb["Fruit"]

mydict=[{"Item":"Oranges","Price":2.99},
        {"Item":"Apple","Price":1.99},
        {"Item":"Banana","Price":3.99},
        {"Item":"Plum","price":1.99},
        {"Item":"Mango","Price":8.99},]

mycol.insert_many(mydict)
mycol.update


[print(i) for i in x]

#Remember to uncommment and comment line at the bottom
#mycol.drop()

# %%
import pymongo

myclient = pymongo.MongoClient("mongodb://localhost:27017/")
mydb = myclient["Data_Tracker"]
mycol = mydb["Vegtables"]

mydict=[{"Item":"Spinuch","Price":9.99},
        {"Item":"Cabbage","Price":9.99},
        {"Item":"Carrots","Price":6.99},
        {"Item":"Cucamba","price":10.99},
        {"Item":"Avocado","Price":9.99},]

mycol.insert_many(mydict)
mycol.update


[print(i) for i in x]

#Remember to uncommment and comment line at the bottom
#mycol.drop()

# %%
import pymongo

myclient = pymongo.MongoClient("mongodb://localhost:27017/")
mydb = myclient["Data_Tracker"]
mycol = mydb["All items"]


mydict=[{"Product":"Simba","Prices":16.99,"Quantity":50,"Barcode":2914,"Weight":125},
        {"Product":"Lays","Price":14.99,"Quantity":20,"Barcode":2909,"Weight":125},
        {"Product":"Pringle","Prices":21.99,"Quantity":25,"Barcode":3210,"Weight":150},
        {"Product":"Doritos","Price":19.99,"Quantity":15,"Barcode":9145,"Weight":90},
        {"Product":"Chetos","Prices":10.99,"Quantity":10,"Barcode":3600,"Weight":90},
        {"Product":"Sprite","Price":14.99,"Quantity":10,"Barcode":3600,"Weight":330},
        {"Product":"Fanta","Prices":14.99,"Quantity":15,"Barcode":2900,"Weight":330},
        {"Product":"Coke","Prices":20.99,"Quantity":20,"Barcode":9146,"Weight":330},
        {"Product":"Powerade","Price":10.99,"Quantity":10,"Barcode":5419,"Weight":250},
        {"Product":"Jive","Prices":9.99,"Quantity":8,"Barcode":7856,"Weight":330},
        {"Product":"Cudbury","Price":15.99,"Quantity":10,"Barcode":3468,"Weight":9},
        {"Product":"Dark Choc","Prices":14.99,"Quantity":5,"Barcode":9022,"Weight":95},
        {"Product":"Bar one","Price":8.99,"Quantity":6,"Barcode":1492,"Weight":30},
        {"Product":"Lunch Bar","Prices":9.99,"Quantity":7,"Barcode":1600,"Weight":20},
        {"Product":"Tax","Price":7.99,"Quantity":6,"Barcode":1677,"Weight":30},
        {"Product":"Steak","Prices":16.99,"Quantity":15,"Barcode":1213,"Weight":330},
        {"Product":"Chicken pie","Price":16.99,"Quantity":16,"Barcode":9022,"Weight":330},
        {"Product":"Cheese Berga","Prices":18.99,"Quantity":7,"Barcode":1492,"Weight":330},
        {"Product":"Chry pie","Price":18.99,"Quantity":4,"Barcode":120,"Weight":330},
        {"Product":"Chicken & Mash","Prices":15.99,"Quantity":20,"Barcode":188,"Weight":330},
        {"Product":"Oranges","Price":2.99,"Quantity":50,"Barcode":201,"Weight":10},
        {"Product":"Apple","Prices":1.99,"Quantity":30,"Barcode":444,"Weight":7},
        {"Product":"Banana","Price":3.99,"Quantity":20,"Barcode":440,"Weight":50},
        {"Product":"Plum","Prices":1.99,"Quantity":50,"Barcode":3600,"Weight":90},
        {"Product":"Mango","Price":8.99,"Quantity":10,"Barcode":2903,"Weight":330},
        {"Product":"Spinach","Prices":9.99,"Quantity":5,"Barcode":3014,"Weight":50},
        {"Product":"Cabbage","Prices":9.99,"Quantity":5,"Barcode":1817,"Weight":30},
        {"Product":"Carrots","Prices":6.99,"Quantity":10,"Barcode":1612,"Weight":10},
        {"Product":"Cucamba","Price":10.99,"Quantity":13,"Barcode":170,"Weight":30},
        {"Product":"Avocado","Prices":9.99,"Quantity":10,"Barcode":1100,"Weight":330},]

mycol.insert_many(mydict)
mycol.update


[print(i) for i in x]

#Remember to uncommment and comment line at the bottom
#mycol.drop()

# %%
import pymongo

myclient = pymongo.MongoClient("mongodb://localhost:27017/")
mydb = myclient["Data_Tracker"]
mycol = mydb["Top 3 Collection"]

mydict=[{"Product":"Simba","Prices":16.99,"Quantity":50,"Barcode":2914,"Weight":125},
       {"Product":"Fanta","Prices":14.99,"Quantity":15,"Barcode":2900,"Weight":330},
       {"Product":"Bar one","Price":8.99,"Quantity":6,"Barcode":1492,"Weight":30},]

mycol.insert_many(mydict)
x = mycol.find()

[print(i) for i in x]

# %%
import pymongo

myclient = pymongo.MongoClient("mongodb://localhost:27017/")

mydb = myclient["Data_Tracker"]

mycol=mydb["Top 3 Collection"]
myquery={"Type":"Simba", "Quantity":50,"Price":16.99,"Barcode":2914,"Weight":125},

x=mycol.delete_one(myquery)
print(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-c1e39ed077c3> in <module>
#       8 myquery={"Type":"Simba", "Quantity":50,"Price":16.99,"Barcode":2914,"Weight":125},
#       9
# ---> 10 x=mycol.delete_one(myquery)
#      11 print(x)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pymongo\collection.py in delete_one(self, filter, collation)
#    1031         with self._socket_for_writes() as sock_info:
#    1032             return DeleteResult(self._delete(sock_info, filter, False,
# -> 1033                                              collation=collation),
#    1034                                 self.write_concern.acknowledged)
#    1035
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pymongo\collection.py in _delete(self, sock_info, criteria, multi, write_concern, op_id, ordered, collation)
#     967             collation=None):
# ...
